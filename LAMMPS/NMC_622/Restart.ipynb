# %%
# !pip install ase
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 21.3 MB/s eta 0:00:00
# ...

# %%
from ase.io import read, write

# Read final frame from your dump file
atoms = read("dump.nmc_622_500ksteps_300K.lammpstrj", format="lammps-dump-text", index=-1)

# Write it as a LAMMPS data file
write("conf_restart.lmp", atoms, format="lammps-data", atom_style="atomic")
